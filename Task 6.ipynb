# %% [markdown]
# The Sparks Foundation
#  Name: Renuka Devi Bommisetty
#  Email: renukasreenivas56@gmail.com
#  Domain: Data Science And Business Analytics
#  Task-2: Prediction using unsupervised ML

# %% [markdown]
# # Importing Data

# %%
import pyforest

# %%
data=pd.read_csv("c://Users/RENUKA SREENIVAS/Downloads/iris.csv")
data.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
data.tail(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
shape=data.shape
shape
# Out:
# (150, 6)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.describe(include="all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
data.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
data["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
avg_sepal_length=(data["SepalLengthCm"].sum())/(shape[0])
avg_sepal_length
# Out:
# 5.843333333333334

# %%
avg_sepal_width=(data["SepalWidthCm"].sum())/(shape[0])
avg_sepal_width
# Out:
# 3.0540000000000003

# %%
avg_petal_length=(data["PetalLengthCm"].sum())/(shape[0])
avg_petal_length
# Out:
# 3.758666666666666

# %%
avg_petal_width=(data["PetalWidthCm"].sum())/(shape[0])
avg_petal_width
# Out:
# 1.1986666666666668

# %% [markdown]
# Data Visualisation

# %%
a=sns.violinplot(y="Species",x="SepalLengthCm",data=data,inner="quartile")
plt.show()
b=sns.violinplot(y="Species",x="SepalWidthCm",data=data,inner="quartile")
plt.show()
c=sns.violinplot(y="Species",x="PetalLengthCm",data=data,inner="quartile")
plt.show()
d=sns.violinplot(y="Species",x="PetalWidthCm",data=data,inner="quartile")
plt.show()

# %%
sns.scatterplot(x=data["SepalLengthCm"],y=data["SepalWidthCm"],hue=data["Species"])

# %%
sns.scatterplot(x=data["PetalLengthCm"],y=data["PetalWidthCm"],hue=data["Species"])

# %%
sns.lmplot(x="SepalLengthCm",y="SepalWidthCm",hue="Species",data=data,height=5)

# %%
sns.lmplot(x="PetalLengthCm",y="PetalWidthCm",hue="Species",data=data,height=5)

# %%
sns.boxplot(x="PetalLengthCm",y="Species",data=data)
plt.title("Petal length of different Iris Species")
# Out:
# Text(0.5, 1.0, 'Petal length of different Iris Species')

# %%
sns.boxplot(x="PetalWidthCm",y="Species",data=data)
plt.title("Petal width of different Iris Species")
# Out:
# Text(0.5, 1.0, 'Petal width of different Iris Species')

# %%
sns.boxplot(x="SepalLengthCm",y="Species",data=data)
plt.title("Sepal length of different Iris Species")
# Out:
# Text(0.5, 1.0, 'Sepal length of different Iris Species')

# %%
sns.boxplot(x="SepalWidthCm",y="Species",data=data)
plt.title("Sepal width of different Iris Species")
# Out:
# Text(0.5, 1.0, 'Sepal width of different Iris Species')

# %%
sns.pairplot(data,hue="Species")

# %% [markdown]
# # Decision Tree Algorithm

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
data=data.apply(lb.fit_transform)

# %%
x=data.drop(["Id","Species"],axis=1)
y=data["Species"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2])

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.9736842105263158

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.94      0.97        16
#            2       0.90      1.00      0.95         9
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
from sklearn import tree
plt.figure(figsize=(20,10))
tree.plot_tree(model,feature_names=data.columns,filled=True);
